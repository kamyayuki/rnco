# %% [markdown]
# <a href="https://colab.research.google.com/github/kamyayuki/rnco/blob/main/L2/Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import requests
#
# # Пример запроса к TCIA API

# %% [markdown]
# The Cancer Imaging Archive (TCIA) предоставляет доступ к медицинским изображениям через API. Вы можете использовать библиотеку requests для загрузки данных из TCIA:

# %%
import requests

# Пример запроса к TCIA API
url = "https://services.cancerimagingarchive.net/services/v3/TCIA/query/getSeries?Collection=TCGA-BRCA"
response = requests.get(url)

# Проверка ответа
if response.status_code == 200:
    print("Данные получены успешно")
else:
    print("Ошибка получения данных")
# Out:
# Данные получены успешно

# %% [markdown]
# Данные приходят в JSON формате.
# В этом примере запрос отправляется с параметром format=json, чтобы вернуть данные в формате JSON.
# Преобразование ответа в JSON:
# response.json() позволяет конвертировать ответ в словарь Python, с которым будем работать дальше.
# Обработка JSON-ответа:
# Сначала печатаем весь JSON для ознакомления.

# %%
import requests
import json

# Пример запроса к TCIA API, предполагающий JSON формат
url = "https://services.cancerimagingarchive.net/services/v3/TCIA/query/getSeries?Collection=TCGA-BRCA&format=json"
response = requests.get(url)

# Проверка ответа
if response.status_code == 200:
    print("Данные получены успешно")

    # Преобразование ответа в JSON
    data = response.json()
    print(json.dumps(data, indent=4))  # Печать данных в формате JSON с отступами

    # Обработка данных
    for item in data:
        series_instance_uid = item.get('SeriesInstanceUID', 'N/A')
        modality = item.get('Modality', 'N/A')
        protocol_name = item.get('ProtocolName', 'N/A')
        body_part_examined = item.get('BodyPartExamined', 'N/A')

        # Печать извлеченной информации
        print(f"SeriesInstanceUID: {series_instance_uid}")
        print(f"Modality: {modality}")
        print(f"ProtocolName: {protocol_name}")
        print(f"BodyPartExamined: {body_part_examined}")
        print('-' * 30)
else:
    print("Ошибка получения данных")
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.240831734808981235886758156447
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.339963655672432655223423353554
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.325607836963460379034020654281
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.282877615330280376078734696973
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.199532769200268583433474778786
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.108665300491756890793844513467
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.300268162257258819734468034177
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.339281196101526063217949717515
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.135731461272336252652455384603
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.173608707719131037216181286801
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.224514938117348685752758980907
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.216808278210582422541188816094
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.118616195199518869715400190332
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.473399958042716665168331548723
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.704314353700237555193682673086
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.968233762954796374562360095520
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.180755434014359981139880681168
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.847225588986595558313443586336
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.277480657439823093318428528463
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.765557706501997422547752773465
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.331479872549123551096980584577
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.238125138226958471892709616892
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.118659073978645834432460929239
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.277715863301926133011067938823
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.876312572685752643717401031802
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.102895244054883066169058953347
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.147504212526318092694183312516
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.186599640298298130582367548922
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.327702862097509894679488137700
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.265963154110062013582166845425
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.168133932292774895008867110168
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.185124923114242904116583970712
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.887105171326956481013826792518
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.970234619425453112334335197265
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.117401252223788963396100123623
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.326965958944129163933043155653
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.173811469988744602117102368236
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.217825448458813044679968287572
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.722090851796098655847916893588
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.313282352812647399365293194724
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.102149938257790290974007969715
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.101612527905308942254141087199
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.310087920752735856086807386491
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.139977785652854094779718423453
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.100105825865314746163545447682
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.166938873733752390819528694627
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.263738690753989997240996788475
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.132086475408627369234981637714
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.329399909920065311882968480483
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.123374396643043094975171978664
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.135174102168200634719973577180
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.324782910856026783332544732931
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.183537298591498929237121248101
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.816771669497046065365204301192
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.105153869491383615093890386014
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.164884599509906584549276916124
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.287505788571546294034881701053
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.246376574203599302535933215914
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.882122419180137606189634174220
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.279539954255024560959719856433
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.310854888519618590153504603476
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.272988075162192954057756598308
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.151997448002318053251165577910
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.150177562545293408758205796359
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.292298692937100715728922684007
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.839041236716764520061702363505
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.201721521431660615596412381736
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002.156749341608331097058771541482
# Modality: MR
# ProtocolName: N/A
# BodyPartExamined: BREAST
# ------------------------------
# SeriesInstanceUID: 1.3.6.1.4.1.14519.5.2.1.6450.4002